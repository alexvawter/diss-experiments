# %%
import pandas as pd
import numpy as np
import json 

import gzip
import io

import sqlite3
sql_conn = sqlite3.connect(":memory:")

import urllib.request

# %%
#all plotting imports
# %matplotlib inline

import matplotlib 
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')

import os
import folium

print(folium.__version__)
# Out:
# 0.5.0

# %%
lon, lat = -38.625, -12.875

zoom_start = 8

# %%
df = pd.read_csv("https://raw.githubusercontent.com/alexvawter/dh-course-fall-2017/master/isaw-maps/vawter-places-isaw-8.csv")
df
# Out:
#              name        lat       long       uri
# 0          Edessa  37.162557  38.781432  658457.0
# 1         Ephesus  37.942100  27.345513  599612.0
# 2  Constantinople  41.006311  28.959006  520998.0
# 3         Antioch  36.201380  36.161749  658381.0
# 4           Sinai  29.500000  34.000000  746813.0
# 5        Caesarea  37.252503  35.903735  658378.0
# 6       Tabennisi  32.380180  26.099698  786125.0
# 7      Alexandria  31.120000  29.550000       NaN
# 8         Cucusus  38.011600  36.293000       NaN
# 9           Sohag  26.330000  31.420000       NaN

# %%
m = folium.Map(location=[20, 0], tiles="Mapbox Bright", zoom_start=2)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for index, row in df.iterrows():
    folium.Marker([row['lat'], row['long']], 
                  popup=row['name'],
                  icon=folium.Icon(color='gray')
                 ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data = pd.read_json

# %%
df = pd.read_csv("https://raw.githubusercontent.com/alexvawter/dh-course-fall-2017/master/isaw-maps/vawter-places-isaw-8.csv")
site_lat = df.lat
site_lon = df.long
locations_name = df.name

# %%
df.iloc[:5]
# Out:
#              name        lat       long       uri
# 0          Edessa  37.162557  38.781432  658457.0
# 1         Ephesus  37.942100  27.345513  599612.0
# 2  Constantinople  41.006311  28.959006  520998.0
# 3         Antioch  36.201380  36.161749  658381.0
# 4           Sinai  29.500000  34.000000  746813.0
